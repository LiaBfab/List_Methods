# %% [markdown]
# <h2> Question: </h2>
# <p> Kindly provide 10 different examples each, for all the List methods we treated in class. </p>
#
# <h2> Solution: </h2>

# %%
#Creation of List: 

extras = [1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
numbers = [2.3, 4.445, 3, 5.33, 2, -3, 1809]
vegies = ['Ash gourd', 'Broccoli', 'Potato', 'Capsicum', 'Turnip']
fruits= ['Apple', 'Orange', 'Banana', 'Mango', 'Watermelon']
languages = ['Python', 'Swift', 'C++', 'Java', 'Kotlin']
animals = ['Dog', 'Cow', 'Cat', 'Donkey', 'Tiger']
shapes = ['Nonagon', 'Octagon', 'Heptagon', 'Hexagon', 'Triangle']
mixed1 = [1854, -11, 'Ruby', 'Panther', 'Pentagon']
mixed2 = [7, -13, ['Cluster beans', 'Kiwi']]
mixed3 = [[8, 152], [-21, -109]]
randoms =  [ 5, 'Ginger', 'Needle', 'Drawer',]

# %% [markdown]
# <h5> 1) Append() Method </h5>

# %%
#append: Example 1
vegies.append('Green peas')
print('Example 1 = ', vegies)

#append: Example 2
numbers.append(-2.5)
print('Example 2 = ', numbers)

#append: Example 3
fruits.append('Pineapple')
print('Example 3 = ', fruits)

#append: Example 4
languages.append('Javascript')
print('Example 4 = ', languages)

#append: Example 5
animals.append('Lion')
print('Example 5 = ', animals)

#append: Example 6
shapes.append('Square')
print('Example 6 = ', shapes)

#append: Example 7
mixed1.append('Tray')
print('Example 7 = ', mixed1)

#append: Example 8
mixed2.append(7.054)
print('Example 8 = ', mixed2)

#append: Example 9
mixed3.append(['Papaya', 'Blueberry'])
print('Example 9 = ', mixed3)

#append: Example 10
randoms.append('Tree')
print('Example 10 = ', randoms)
# Out:
# Example 1 =  ['Ash gourd', 'Broccoli', 'Potato', 'Capsicum', 'Turnip', 'Green peas']
# Example 2 =  [2.3, 4.445, 3, 5.33, 2, -3, 1809, -2.5]
# Example 3 =  ['Apple', 'Orange', 'Banana', 'Mango', 'Watermelon', 'Pineapple']
# Example 4 =  ['Python', 'Swift', 'C++', 'Java', 'Kotlin', 'Javascript']
# Example 5 =  ['Dog', 'Cow', 'Cat', 'Donkey', 'Tiger', 'Lion']
# Example 6 =  ['Nonagon', 'Octagon', 'Heptagon', 'Hexagon', 'Triangle', 'Square']
# Example 7 =  [1854, -11, 'Ruby', 'Panther', 'Pentagon', 'Tray']
# Example 8 =  [7, -13, ['Cluster beans', 'Kiwi'], 7.054]
# Example 9 =  [[8, 152], [-21, -109], ['Papaya', 'Blueberry']]
# Example 10 =  [5, 'Ginger', 'Needle', 'Drawer', 'Tree']

# %% [markdown]
# <h5> 2) Insert() Method </h5>

# %%
#insert: Example 1
vegies.insert(-2,'Pepper')
print('Example 1 = ', vegies)

#insert: Example 2
numbers.insert(-2, -19754)
print('Example 2 = ', numbers)

#insert: Example 3
fruits.insert(5, 'Pear')
print('Example 3 = ', fruits)

#insert: Example 4
languages.insert(2, 'Javascript')
print('Example 4 = ', languages)

#insert: Example 5
animals.insert(1, 'Sheep')
print('Example 5 = ', animals)

#insert: Example 6
shapes.insert(5, 'Circle')
print('Example 6 = ', shapes)

#insert: Example 7
mixed1.insert(3, 0.054)
print('Example 7 = ', mixed1)

#insert: Example 8
mixed2.insert(-1, 54)
print('Example 8 = ', mixed2)

#insert: Example 9
mixed3.insert(3, ['Pine', 'Berry'])
print('Example 9 = ', mixed3)

#insert: Example 10
randoms.insert(2, 'Sun glasses')
print('Example 10 = ', randoms)
# Out:
# Example 1 =  ['Ash gourd', 'Broccoli', 'Potato', 'Capsicum', 'Pepper', 'Turnip', 'Green peas']
# Example 2 =  [2.3, 4.445, 3, 5.33, 2, -3, -19754, 1809, -2.5]
# Example 3 =  ['Apple', 'Orange', 'Banana', 'Mango', 'Watermelon', 'Pear', 'Pineapple']
# Example 4 =  ['Python', 'Swift', 'Javascript', 'C++', 'Java', 'Kotlin', 'Javascript']
# Example 5 =  ['Dog', 'Sheep', 'Cow', 'Cat', 'Donkey', 'Tiger', 'Lion']
# Example 6 =  ['Nonagon', 'Octagon', 'Heptagon', 'Hexagon', 'Triangle', 'Circle', 'Square']
# Example 7 =  [1854, -11, 'Ruby', 0.054, 'Panther', 'Pentagon', 'Tray']
# Example 8 =  [7, -13, ['Cluster beans', 'Kiwi'], 54, 7.054]
# Example 9 =  [[8, 152], [-21, -109], ['Papaya', 'Blueberry'], ['Pine', 'Berry']]
# Example 10 =  [5, 'Ginger', 'Sun glasses', 'Needle', 'Drawer', 'Tree']

# %% [markdown]
# <h5> 3) Index() Method</h5>

# %%
#index: Example 1
index1 = vegies.index('Pepper')
print('Example 1 = ', index1)

#index: Example 2
index2 = numbers.index(-2.5)
print('Example 2 = ', index2)

#index: Example 3
index3 = fruits.index('Pear')
print('Example 3 = ', index3)

#index: Example 4
index4 = languages.index('Javascript')
print('Example 4 = ', index4)

#index: Example 5
index5 = animals.index('Sheep')
print('Example 5 = ', index5)

#index: Example 6
index6 = shapes.index('Circle')
print('Example 6 = ', index6)

#index: Example 7
index7 = mixed1.index(0.054)
print('Example 7 = ', index7)

#index: Example 8
index8 = mixed2.index(54)
print('Example 8 = ', index8)

#index: Example 9
index9 = mixed3.index(['Pine', 'Berry'])
print('Example 9 = ', index9)

#index: Example 10
index10 = randoms.index('Sun glasses')
print('Example 10 = ', index10)
# Out:
# Example 1 =  4
# Example 2 =  8
# Example 3 =  5
# Example 4 =  2
# Example 5 =  1
# Example 6 =  5
# Example 7 =  3
# Example 8 =  3
# Example 9 =  3
# Example 10 =  2

# %% [markdown]
# <h5> 4) Pop() Method</h5>

# %%
#pop: Example 1
popped1 = vegies.pop()
print('Example 1 = ', popped1)
print(vegies)

#pop: Example 2
popped2 = numbers.pop(-2)
print('Example 2 = ', popped2)
print(numbers)

#pop: Example 3
popped3 = fruits.pop(0)
print('Example 3 = ', popped3)
print(fruits)

#pop: Example 4
popped4 = languages.pop(5)
print('Example 4 = ', popped4)
print(languages)

#pop: Example 5
popped5 = animals.pop(1)
print('Example 5 = ', popped5)
print(animals)

#pop: Example 6
popped6 = shapes.pop(6)
print('Example 6 = ', popped6)
print(shapes)

#pop: Example 7
popped7 = mixed1.pop(3)
print('Example 7 = ', popped7)
print(mixed1)

#pop: Example 8
popped8 = mixed2.pop(1)
print('Example 8 = ', popped8)
print(mixed2)

#pop: Example 9
popped9 = mixed3.pop(1)
print('Example 9 = ', popped9)
print(mixed3)

#pop: Example 10
popped10 = randoms.pop(0)
print('Example 10 = ', popped10)
print(randoms)
# Out:
# Example 1 =  Green peas
# ['Ash gourd', 'Broccoli', 'Potato', 'Capsicum', 'Pepper', 'Turnip']
# Example 2 =  1809
# [2.3, 4.445, 3, 5.33, 2, -3, -19754, -2.5]
# Example 3 =  Apple
# ['Orange', 'Banana', 'Mango', 'Watermelon', 'Pear', 'Pineapple']
# Example 4 =  Kotlin
# ['Python', 'Swift', 'Javascript', 'C++', 'Java', 'Javascript']
# Example 5 =  Sheep
# ['Dog', 'Cow', 'Cat', 'Donkey', 'Tiger', 'Lion']
# Example 6 =  Square
# ['Nonagon', 'Octagon', 'Heptagon', 'Hexagon', 'Triangle', 'Circle']
# Example 7 =  0.054
# [1854, -11, 'Ruby', 'Panther', 'Pentagon', 'Tray']
# Example 8 =  -13
# [7, ['Cluster beans', 'Kiwi'], 54, 7.054]
# Example 9 =  [-21, -109]
# [[8, 152], ['Papaya', 'Blueberry'], ['Pine', 'Berry']]
# Example 10 =  5
# ['Ginger', 'Sun glasses', 'Needle', 'Drawer', 'Tree']

# %% [markdown]
# <h5> 5) Remove() Method</h5>

# %%
#remove: Example 1
vegies.remove('Capsicum')
print('Example 1 = ', vegies)

#remove: Example 2
numbers.remove(-2.5)
print('Example 2 = ', numbers)

#remove: Example 3
fruits.remove('Watermelon')
print('Example 3 = ', fruits)

#remove: Example 4
languages.remove('Swift')
print('Example 4 = ', languages)

#remove: Example 5
animals.remove('Donkey')
print('Example 5 = ', animals)

#remove: Example 6
shapes.remove('Octagon')
print('Example 6 = ', shapes)

#remove: Example 7
mixed1.remove(-11)
print('Example 7 = ', mixed1)

#remove: Example 8
mixed2.remove(['Cluster beans', 'Kiwi'])
print('Example 8 = ', mixed2)

#remove: Example 9
mixed3.remove(['Pine', 'Berry'])
print('Example 9 = ', mixed3)

#remove: Example 10
randoms.remove('Tree')
print('Example 10 = ', randoms)
# Out:
# Example 1 =  ['Ash gourd', 'Broccoli', 'Potato', 'Pepper', 'Turnip']
# Example 2 =  [2.3, 4.445, 3, 5.33, 2, -3, -19754]
# Example 3 =  ['Orange', 'Banana', 'Mango', 'Pear', 'Pineapple']
# Example 4 =  ['Python', 'Javascript', 'C++', 'Java', 'Javascript']
# Example 5 =  ['Dog', 'Cow', 'Cat', 'Tiger', 'Lion']
# Example 6 =  ['Nonagon', 'Heptagon', 'Hexagon', 'Triangle', 'Circle']
# Example 7 =  [1854, 'Ruby', 'Panther', 'Pentagon', 'Tray']
# Example 8 =  [7, 54, 7.054]
# Example 9 =  [[8, 152], ['Papaya', 'Blueberry']]
# Example 10 =  ['Ginger', 'Sun glasses', 'Needle', 'Drawer']

# %% [markdown]
# <h5> 6) Modify() Method</h5>

# %%
#modify: Example 1
vegies[1] = ('Pumpkin')
print('Example 1 = ', vegies)

#modify: Example 2
numbers[0] = (17.5)
print('Example 2 = ', numbers)

#modify: Example 3
fruits[3] = ('Watermelon')
print('Example 3 = ', fruits)

#modify: Example 4
languages[-1] = ('Swift')
print('Example 4 = ', languages)

#modify: Example 5
animals[1] = ('Donkey')
print('Example 5 = ', animals)

#modify: Example 6
shapes[3] = ('Octagon')
print('Example 6 = ', shapes)

#modify: Example 7
mixed1[0] = ('Diamond')
print('Example 7 = ', mixed1)

#modify: Example 8
mixed2[-3:] = (783, -11, 1980, 1)
print('Example 8 = ', mixed2)

#modify: Example 9
mixed3[:1] = (['Pine', 'Berry'], ['Cluster beans', 'Kiwi'])
print('Example 9 = ', mixed3)

#modify: Example 10
randoms[2] = ('Tree')
print('Example 10 = ', randoms)
# Out:
# Example 1 =  ['Ash gourd', 'Pumpkin', 'Potato', 'Pepper', 'Turnip']
# Example 2 =  [17.5, 4.445, 3, 5.33, 2, -3, -19754]
# Example 3 =  ['Orange', 'Banana', 'Mango', 'Watermelon', 'Pineapple']
# Example 4 =  ['Python', 'Javascript', 'C++', 'Java', 'Swift']
# Example 5 =  ['Dog', 'Donkey', 'Cat', 'Tiger', 'Lion']
# Example 6 =  ['Nonagon', 'Heptagon', 'Hexagon', 'Octagon', 'Circle']
# Example 7 =  ['Diamond', 'Ruby', 'Panther', 'Pentagon', 'Tray']
# Example 8 =  [783, -11, 1980, 1]
# Example 9 =  [['Pine', 'Berry'], ['Cluster beans', 'Kiwi'], ['Papaya', 'Blueberry']]
# Example 10 =  ['Ginger', 'Sun glasses', 'Tree', 'Drawer']

# %% [markdown]
# <h5> 7) Sort() Method</h5>

# %%
#sort: Example 1
vegies.sort()
print('Example 1 = ', vegies)

#sort: Example 2
numbers.sort()
print('Example 2 = ', numbers)

#sort: Example 3
fruits.sort()
print('Example 3 = ', fruits)

#sort: Example 4
languages.sort()
print('Example 4 = ', languages)

#sort: Example 5
animals.sort()
print('Example 5 = ', animals)

#sort: Example 6
shapes.sort()
print('Example 6 = ', shapes)

#sort: Example 7
mixed1.sort()
print('Example 7 = ', mixed1)

#sort: Example 8
mixed2.sort()
print('Example 8 = ', mixed2)

#sort: Example 9
mixed3.sort()
print('Example 9 = ', mixed3)

#sort: Example 10
randoms.sort()
print('Example 10 = ',randoms)
# Out:
# Example 1 =  ['Ash gourd', 'Pepper', 'Potato', 'Pumpkin', 'Turnip']
# Example 2 =  [-19754, -3, 2, 3, 4.445, 5.33, 17.5]
# Example 3 =  ['Banana', 'Mango', 'Orange', 'Pineapple', 'Watermelon']
# Example 4 =  ['C++', 'Java', 'Javascript', 'Python', 'Swift']
# Example 5 =  ['Cat', 'Dog', 'Donkey', 'Lion', 'Tiger']
# Example 6 =  ['Circle', 'Heptagon', 'Hexagon', 'Nonagon', 'Octagon']
# Example 7 =  ['Diamond', 'Panther', 'Pentagon', 'Ruby', 'Tray']
# Example 8 =  [-11, 1, 783, 1980]
# Example 9 =  [['Cluster beans', 'Kiwi'], ['Papaya', 'Blueberry'], ['Pine', 'Berry']]
# Example 10 =  ['Drawer', 'Ginger', 'Sun glasses', 'Tree']

# %% [markdown]
# <h5> 8) Reverse() Method</h5>

# %%
#reverse: Example 1
vegies.reverse()
print('Example 1 = ', vegies)

#reverse: Example 2
numbers.reverse()
print('Example 2 = ', numbers)

#reverse: Example 3
fruits.reverse()
print('Example 3 = ', fruits)

#reverse: Example 4
languages.reverse()
print('Example 4 = ', languages)

#reverse: Example 5
animals.reverse()
print('Example 5 = ', animals)

#reverse: Example 6
shapes.reverse()
print('Example 6 = ', shapes)

#reverse: Example 7
mixed1.reverse()
print('Example 7 = ', mixed1)

#reverse: Example 8
mixed2.reverse()
print('Example 8 = ', mixed2)

#reverse: Example 9
mixed3.reverse()
print('Example 9 = ', mixed3)

#reverse: Example 10
randoms.reverse()
print('Example 10 = ',randoms)
# Out:
# Example 1 =  ['Turnip', 'Pumpkin', 'Potato', 'Pepper', 'Ash gourd']
# Example 2 =  [17.5, 5.33, 4.445, 3, 2, -3, -19754]
# Example 3 =  ['Watermelon', 'Pineapple', 'Orange', 'Mango', 'Banana']
# Example 4 =  ['Swift', 'Python', 'Javascript', 'Java', 'C++']
# Example 5 =  ['Tiger', 'Lion', 'Donkey', 'Dog', 'Cat']
# Example 6 =  ['Octagon', 'Nonagon', 'Hexagon', 'Heptagon', 'Circle']
# Example 7 =  ['Tray', 'Ruby', 'Pentagon', 'Panther', 'Diamond']
# Example 8 =  [1980, 783, 1, -11]
# Example 9 =  [['Pine', 'Berry'], ['Papaya', 'Blueberry'], ['Cluster beans', 'Kiwi']]
# Example 10 =  ['Tree', 'Sun glasses', 'Ginger', 'Drawer']

# %% [markdown]
# <h5> 9) Extend() Method</h5>

# %%
#extend: Example 1
vegies.extend(extras)
print('Example 1 = ', vegies)

#extend: Example 2
numbers.extend(extras)
print('Example 2 = ', numbers)

#extend: Example 3
fruits.extend(extras)
print('Example 3 = ', fruits)

#extend: Example 4
languages.extend(extras)
print('Example 4 = ', languages)

#extend: Example 5
animals.extend(extras)
print('Example 5 = ', animals)

#extend: Example 6
shapes.extend(extras)
print('Example 6 = ', shapes)

#extend: Example 7
mixed1.extend(extras)
print('Example 7 = ', mixed1)

#extend: Example 8
mixed2.extend(extras)
print('Example 8 = ', mixed2)

#extend: Example 9
mixed3.extend(extras)
print('Example 9 = ', mixed3)

#extend: Example 10
randoms.extend(extras)
print('Example 10 = ',randoms)
# Out:
# Example 1 =  ['Turnip', 'Pumpkin', 'Potato', 'Pepper', 'Ash gourd', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 2 =  [17.5, 5.33, 4.445, 3, 2, -3, -19754, 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 3 =  ['Watermelon', 'Pineapple', 'Orange', 'Mango', 'Banana', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 4 =  ['Swift', 'Python', 'Javascript', 'Java', 'C++', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 5 =  ['Tiger', 'Lion', 'Donkey', 'Dog', 'Cat', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 6 =  ['Octagon', 'Nonagon', 'Hexagon', 'Heptagon', 'Circle', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 7 =  ['Tray', 'Ruby', 'Pentagon', 'Panther', 'Diamond', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 8 =  [1980, 783, 1, -11, 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# ...

# %% [markdown]
# <h5> 10) Count() Method</h5>

# %%
#count: Example 1
count1 = vegies.count('Turnip')
print('The count of Example 1 is ', count1)

#count: Example 2
count2 = numbers.count(4.445)
print('The count of Example 2 is ', count2)

#count: Example 3
count3 = fruits.count('Pear')
print('The count of Example 3 is ', count3)

#count: Example 4
count4 = languages.count('Java')
print('The count of Example 4 is ', count4)

#count: Example 5
count5 = animals.count('Tiger')
print('The count of Example 5 is ', count5)

#count: Example 6
count6 = shapes.count('Circle')
print('The count of Example 6 is ', count6)

#count: Example 7
count7 = mixed1.count('Tray')
print('The count of Example 7 is ', count7)

#count: Example 8
count8 = mixed2.count(1)
print('The count of Example 8 is ', count8)

#count: Example 9
count9 = mixed3.count(['Pine', 'Berry'])
print('The count of Example 9 is ', count9)

#count: Example 10
count10 = randoms.count('Drawer')
print('The count of Example 10 is ', count10)
# Out:
# The count of Example 1 is  1
# The count of Example 2 is  2
# The count of Example 3 is  0
# The count of Example 4 is  2
# The count of Example 5 is  2
# The count of Example 6 is  2
# The count of Example 7 is  1
# The count of Example 8 is  3
# The count of Example 9 is  1
# The count of Example 10 is  2

# %% [markdown]
# <h5> 11) Copy() Method</h5>

# %%
#copy: Example 1
copy1 = vegies.copy()
print('Example 1 copied = ', copy1)

#count: Example 2
copy2 = numbers.copy()
print('Example 2 copied = ', copy2)

#count: Example 3
copy3 = fruits.copy()
print('Example 3 copied = ', copy3)

#count: Example 4
copy4 = languages.copy()
print('Example 4 copied = ', copy4)

#count: Example 5
copy5 = animals.copy()
print('Example 5 copied = ', copy5)

#count: Example 6
copy6 = shapes.copy()
print('Example 6 copied = ', copy6)

#count: Example 7
copy7 = mixed1.copy()
print('Example 7 copied = ', copy7)

#count: Example 8
copy8 = mixed2.copy()
print('Example 8 copied = ', copy8)

#count: Example 9
copy9 = mixed3.copy()
print('Example 9 copied = ', copy9)

#count: Example 10
copy10 = randoms.copy()
print('Example 10 copied = ', copy10)
# Out:
# Example 1 copied =  ['Turnip', 'Pumpkin', 'Potato', 'Pepper', 'Ash gourd', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 2 copied =  [17.5, 5.33, 4.445, 3, 2, -3, -19754, 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 3 copied =  ['Watermelon', 'Pineapple', 'Orange', 'Mango', 'Banana', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 4 copied =  ['Swift', 'Python', 'Javascript', 'Java', 'C++', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 5 copied =  ['Tiger', 'Lion', 'Donkey', 'Dog', 'Cat', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 6 copied =  ['Octagon', 'Nonagon', 'Hexagon', 'Heptagon', 'Circle', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 7 copied =  ['Tray', 'Ruby', 'Pentagon', 'Panther', 'Diamond', 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# Example 8 copied =  [1980, 783, 1, -11, 1, 4.445, 'Circle', 'Tiger', 'Java', 1, 'Drawer']
# ...

# %% [markdown]
# <h5> 12) Clear() Method</h5>

# %%
#clear: Example 1
vegies.clear()
print('Example 1 after clear() = ', vegies)

#clear: Example 2
numbers.clear()
print('Example 2 after clear() = ', numbers)

#clear: Example 3
fruits.clear()
print('Example 3 after clear() = ', fruits)

#clear: Example 4
languages.clear()
print('Example 4 after clear() = ', languages)

#clear: Example 5
animals.clear()
print('Example 5 after clear() = ', animals)

#clear: Example 6
clear6 = shapes.clear()
print('Example 6 after clear() = ', clear6)

#clear: Example 7
clear7 = mixed1.clear()
print('Example 7 after clear() = ', clear7)

#clear: Example 8
clear8 = mixed2.clear()
print('Example 8 after clear() = ', clear8)

#clear: Example 9
clear9 = mixed3.clear()
print('Example 9 after clear() = ', clear9)

#clear: Example 10
clear10 = randoms.clear()
print('Example 10 after clear() = ', clear10)
# Out:
# Example 1 after clear() =  []
# Example 2 after clear() =  []
# Example 3 after clear() =  []
# Example 4 after clear() =  []
# Example 5 after clear() =  []
# Example 6 after clear() =  None
# Example 7 after clear() =  None
# Example 8 after clear() =  None
# Example 9 after clear() =  None
# Example 10 after clear() =  None
